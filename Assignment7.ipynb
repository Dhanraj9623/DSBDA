# %% [markdown]
# # Text Analytics
# 1. Extract Sample document and apply following document preprocessing methods:
# Tokenization, POS Tagging, stop words removal, Stemming and Lemmatization.
# 2. Create representation of document by calculating Term Frequency and Inverse Document
# Frequency.

# %% [markdown]
# # Import all Python Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/ass7/final_dataset.csv")
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  Factbox: Malaysia 2018 budget seen lifting cas...
# 1               1  White House hopeful Trump nears end of vice pr...
# 2               2  Iran 'hopes Hariri will remain Lebanon's prime...
# 3               3  Former Trump campaign adviser Page to testify ...
# 4               4  THE LIST of 34 House Republicans DEMANDING Per...
# ...           ...                                                ...
# 44893       44893  OH WHAT A DAY! First Family Fourth of July Fir...
# 44894       44894  Rohingya insurgents declare temporary ceasefir...
# 44895       44895  Netanyahu to Putin: Israel may act to curb Ira...
# 44896       44896  UK parliament says government must publish sec...
# 44897       44897  About 30 killed when train derails, catches fi...
#
#                                                     text  true
# 0      KUALA LUMPUR (Reuters) - Malaysia s Prime Mini...     1
# 1      WASHINGTON (Reuters) - Republican Donald Trump...     1
# 2      LONDON (Reuters) - An Iranian official said on...     1
# 3      WASHINGTON (Reuters) - Carter Page, a former f...     1
# 4      Who wants to deport  Dreamers ? Not many peopl...     0
# ...                                                  ...   ...
# 44893  It s been a great July 4th! President Trump is...     0
# 44894  BANGKOK/COX S BAZAR, Bangladesh (Reuters) - Ro...     1
# 44895  SOCHI, Russia (Reuters) - Israeli Prime Minist...     1
# 44896  LONDON (Reuters) - British lawmakers ramped up...     1
# 44897  KINSHASA (Reuters) - About 30 people were kill...     1
#
# [44898 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['title'] = df.title.str.lower()
df['text'] = df.text.str.lower()

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  factbox: malaysia 2018 budget seen lifting cas...
# 1           1  white house hopeful trump nears end of vice pr...
# 2           2  iran 'hopes hariri will remain lebanon's prime...
# 3           3  former trump campaign adviser page to testify ...
# 4           4  the list of 34 house republicans demanding per...
#
#                                                 text  true
# 0  kuala lumpur (reuters) - malaysia s prime mini...     1
# 1  washington (reuters) - republican donald trump...     1
# 2  london (reuters) - an iranian official said on...     1
# 3  washington (reuters) - carter page, a former f...     1
# 4  who wants to deport  dreamers ? not many peopl...     0

# %%
import nltk

nltk.download('punkt')

df['title_sent_token'] = df['title'].apply(nltk.sent_tokenize)
df['title_word_token'] = df['title'].apply(nltk.word_tokenize)

df.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dhanraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    Unnamed: 0                                              title  \
# 0           0  factbox: malaysia 2018 budget seen lifting cas...
# 1           1  white house hopeful trump nears end of vice pr...
# 2           2  iran 'hopes hariri will remain lebanon's prime...
# 3           3  former trump campaign adviser page to testify ...
# 4           4  the list of 34 house republicans demanding per...
#
#                                                 text  true  \
# 0  kuala lumpur (reuters) - malaysia s prime mini...     1
# 1  washington (reuters) - republican donald trump...     1
# 2  london (reuters) - an iranian official said on...     1
# 3  washington (reuters) - carter page, a former f...     1
# 4  who wants to deport  dreamers ? not many peopl...     0
#
#                                     title_sent_token  \
# 0  [factbox: malaysia 2018 budget seen lifting ca...
# 1  [white house hopeful trump nears end of vice p...
# 2  [iran 'hopes hariri will remain lebanon's prim...
# 3  [former trump campaign adviser page to testify...
# 4  [the list of 34 house republicans demanding pe...
#
#                                     title_word_token
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, of,...
# 2  [iran, 'hopes, hariri, will, remain, lebanon, ...
# 3  [former, trump, campaign, adviser, page, to, t...
# 4  [the, list, of, 34, house, republicans, demand...

# %%
nltk.download('averaged_perceptron_tagger')

df['title_word_pos'] = df['title_word_token'].apply(nltk.pos_tag)
df.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dhanraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
#    Unnamed: 0                                              title  \
# 0           0  factbox: malaysia 2018 budget seen lifting cas...
# 1           1  white house hopeful trump nears end of vice pr...
# 2           2  iran 'hopes hariri will remain lebanon's prime...
# 3           3  former trump campaign adviser page to testify ...
# 4           4  the list of 34 house republicans demanding per...
#
#                                                 text  true  \
# 0  kuala lumpur (reuters) - malaysia s prime mini...     1
# 1  washington (reuters) - republican donald trump...     1
# 2  london (reuters) - an iranian official said on...     1
# 3  washington (reuters) - carter page, a former f...     1
# 4  who wants to deport  dreamers ? not many peopl...     0
#
#                                     title_sent_token  \
# 0  [factbox: malaysia 2018 budget seen lifting ca...
# 1  [white house hopeful trump nears end of vice p...
# 2  [iran 'hopes hariri will remain lebanon's prim...
# 3  [former trump campaign adviser page to testify...
# 4  [the list of 34 house republicans demanding pe...
#
#                                     title_word_token  \
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, of,...
# 2  [iran, 'hopes, hariri, will, remain, lebanon, ...
# 3  [former, trump, campaign, adviser, page, to, t...
# 4  [the, list, of, 34, house, republicans, demand...
#
#                                       title_word_pos
# 0  [(factbox, NN), (:, :), (malaysia, NN), (2018,...
# 1  [(white, JJ), (house, NN), (hopeful, JJ), (tru...
# 2  [(iran, NN), ('hopes, NNS), (hariri, VBP), (wi...
# 3  [(former, JJ), (trump, NN), (campaign, NN), (a...
# 4  [(the, DT), (list, NN), (of, IN), (34, CD), (h...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df['title_word_token_stopwords'] = df['title_word_token'].apply(lambda x: [word for word in x if word not in stop_words])

df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dhanraj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
#    Unnamed: 0                                              title  \
# 0           0  factbox: malaysia 2018 budget seen lifting cas...
# 1           1  white house hopeful trump nears end of vice pr...
# 2           2  iran 'hopes hariri will remain lebanon's prime...
# 3           3  former trump campaign adviser page to testify ...
# 4           4  the list of 34 house republicans demanding per...
#
#                                                 text  true  \
# 0  kuala lumpur (reuters) - malaysia s prime mini...     1
# 1  washington (reuters) - republican donald trump...     1
# 2  london (reuters) - an iranian official said on...     1
# 3  washington (reuters) - carter page, a former f...     1
# 4  who wants to deport  dreamers ? not many peopl...     0
#
#                                     title_sent_token  \
# 0  [factbox: malaysia 2018 budget seen lifting ca...
# 1  [white house hopeful trump nears end of vice p...
# 2  [iran 'hopes hariri will remain lebanon's prim...
# 3  [former trump campaign adviser page to testify...
# 4  [the list of 34 house republicans demanding pe...
#
#                                     title_word_token  \
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, of,...
# 2  [iran, 'hopes, hariri, will, remain, lebanon, ...
# 3  [former, trump, campaign, adviser, page, to, t...
# 4  [the, list, of, 34, house, republicans, demand...
#
#                                       title_word_pos  \
# 0  [(factbox, NN), (:, :), (malaysia, NN), (2018,...
# 1  [(white, JJ), (house, NN), (hopeful, JJ), (tru...
# 2  [(iran, NN), ('hopes, NNS), (hariri, VBP), (wi...
# 3  [(former, JJ), (trump, NN), (campaign, NN), (a...
# 4  [(the, DT), (list, NN), (of, IN), (34, CD), (h...
#
#                           title_word_token_stopwords
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, vic...
# 2  [iran, 'hopes, hariri, remain, lebanon, 's, pr...
# 3  [former, trump, campaign, adviser, page, testi...
# 4  [list, 34, house, republicans, demanding, perm...

# %%
nltk.download('wordnet')

df['title_word_stem'] = df['title_word_token_stopwords'].apply(lambda x: [nltk.PorterStemmer().stem(word) for word in x])
df['title_word_lem'] = df['title_word_token_stopwords'].apply(lambda x: [nltk.WordNetLemmatizer().lemmatize(word) for word in x])

df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dhanraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    Unnamed: 0                                              title  \
# 0           0  factbox: malaysia 2018 budget seen lifting cas...
# 1           1  white house hopeful trump nears end of vice pr...
# 2           2  iran 'hopes hariri will remain lebanon's prime...
# 3           3  former trump campaign adviser page to testify ...
# 4           4  the list of 34 house republicans demanding per...
#
#                                                 text  true  \
# 0  kuala lumpur (reuters) - malaysia s prime mini...     1
# 1  washington (reuters) - republican donald trump...     1
# 2  london (reuters) - an iranian official said on...     1
# 3  washington (reuters) - carter page, a former f...     1
# 4  who wants to deport  dreamers ? not many peopl...     0
#
#                                     title_sent_token  \
# 0  [factbox: malaysia 2018 budget seen lifting ca...
# 1  [white house hopeful trump nears end of vice p...
# 2  [iran 'hopes hariri will remain lebanon's prim...
# 3  [former trump campaign adviser page to testify...
# 4  [the list of 34 house republicans demanding pe...
#
#                                     title_word_token  \
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, of,...
# 2  [iran, 'hopes, hariri, will, remain, lebanon, ...
# 3  [former, trump, campaign, adviser, page, to, t...
# 4  [the, list, of, 34, house, republicans, demand...
#
#                                       title_word_pos  \
# 0  [(factbox, NN), (:, :), (malaysia, NN), (2018,...
# 1  [(white, JJ), (house, NN), (hopeful, JJ), (tru...
# 2  [(iran, NN), ('hopes, NNS), (hariri, VBP), (wi...
# 3  [(former, JJ), (trump, NN), (campaign, NN), (a...
# 4  [(the, DT), (list, NN), (of, IN), (34, CD), (h...
#
#                           title_word_token_stopwords  \
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, vic...
# 2  [iran, 'hopes, hariri, remain, lebanon, 's, pr...
# 3  [former, trump, campaign, adviser, page, testi...
# 4  [list, 34, house, republicans, demanding, perm...
#
#                                      title_word_stem  \
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, hous, hope, trump, near, end, vice, pr...
# 2  [iran, 'hope, hariri, remain, lebanon, 's, pri...
# 3  [former, trump, campaign, advis, page, testifi...
# 4  [list, 34, hous, republican, demand, perman, a...
#
#                                       title_word_lem
# 0  [factbox, :, malaysia, 2018, budget, seen, lif...
# 1  [white, house, hopeful, trump, nears, end, vic...
# 2  [iran, 'hopes, hariri, remain, lebanon, 's, pr...
# 3  [former, trump, campaign, adviser, page, testi...
# 4  [list, 34, house, republican, demanding, perma...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform([' '.join(words) for words in df['title_word_lem']])

tfidf_matrix.shape
# Out:
# (44898, 18686)
